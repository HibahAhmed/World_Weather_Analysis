# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
    
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
import time
from datetime import datetime
import requests
# Import the API key.
from config import weather_api_key

# %%
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)
url = f"http://api.openweathermap.org/data/2.5/weather?&appid={weather_api_key}"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"] 
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Conditions": weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | soligalich
# Processing Record 3 of Set 1 | bondo
# Processing Record 4 of Set 1 | soyo
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | tasiilaq
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | jaque
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | aquiraz
# Processing Record 14 of Set 1 | constitucion
# Processing Record 15 of Set 1 | lebu
# Processing Record 16 of Set 1 | karratha
# Processing Record 17 of Set 1 | norman wells
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | helong
# Processing Record 20 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 1 | vardo
# Processing Record 22 of Set 1 | dingle
# Processing Record 23 of Set 1 | hambantota
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | tumbagaan
# Processing Record 26 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 1 | sitka
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | dunedin
# Processing Record 32 of Set 1 | airai
# Processing Record 33 of Set 1 | sao joao da barra
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | portland
# Processing Record 36 of Set 1 | kushima
# Processing Record 37 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 1 | saryshagan
# City not found. Skipping...
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | antsohihy
# Processing Record 42 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 1 | puerto cabezas
# Processing Record 44 of Set 1 | missoula
# Processing Record 45 of Set 1 | cherskiy
# Processing Record 46 of Set 1 | mali
# Processing Record 47 of Set 1 | hasaki
# Processing Record 48 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 1 | narsaq
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | fortuna
# Processing Record 2 of Set 2 | churapcha
# Processing Record 3 of Set 2 | marsa matruh
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | torbay
# Processing Record 6 of Set 2 | apt
# Processing Record 7 of Set 2 | agucadoura
# Processing Record 8 of Set 2 | salalah
# Processing Record 9 of Set 2 | severo-kurilsk
# Processing Record 10 of Set 2 | praia
# Processing Record 11 of Set 2 | carnarvon
# Processing Record 12 of Set 2 | aklavik
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | tarko-sale
# Processing Record 16 of Set 2 | sangar
# Processing Record 17 of Set 2 | dicabisagan
# Processing Record 18 of Set 2 | dzilam gonzalez
# Processing Record 19 of Set 2 | waipawa
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | marawi
# Processing Record 22 of Set 2 | khatanga
# Processing Record 23 of Set 2 | vila velha
# Processing Record 24 of Set 2 | harper
# Processing Record 25 of Set 2 | newport
# Processing Record 26 of Set 2 | takoradi
# Processing Record 27 of Set 2 | punta arenas
# Processing Record 28 of Set 2 | mehamn
# Processing Record 29 of Set 2 | port alfred
# Processing Record 30 of Set 2 | butaritari
# Processing Record 31 of Set 2 | longyearbyen
# Processing Record 32 of Set 2 | ankang
# Processing Record 33 of Set 2 | the valley
# Processing Record 34 of Set 2 | sri aman
# Processing Record 35 of Set 2 | saint george
# Processing Record 36 of Set 2 | mandalgovi
# Processing Record 37 of Set 2 | clyde river
# Processing Record 38 of Set 2 | qaanaaq
# Processing Record 39 of Set 2 | saint-philippe
# Processing Record 40 of Set 2 | kununurra
# Processing Record 41 of Set 2 | ponta do sol
# Processing Record 42 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 2 | hamilton
# Processing Record 44 of Set 2 | alofi
# Processing Record 45 of Set 2 | trud
# Processing Record 46 of Set 2 | acapulco
# Processing Record 47 of Set 2 | mar del plata
# Processing Record 48 of Set 2 | prainha
# Processing Record 49 of Set 2 | lac-megantic
# Processing Record 50 of Set 2 | nador
# Processing Record 1 of Set 3 | kieta
# Processing Record 2 of Set 3 | xining
# Processing Record 3 of Set 3 | muros
# Processing Record 4 of Set 3 | hithadhoo
# Processing Record 5 of Set 3 | codrington
# Processing Record 6 of Set 3 | kodiak
# Processing Record 7 of Set 3 | bathsheba
# Processing Record 8 of Set 3 | tynda
# Processing Record 9 of Set 3 | sao filipe
# Processing Record 10 of Set 3 | kailua
# Processing Record 11 of Set 3 | ketchikan
# Processing Record 12 of Set 3 | sesheke
# Processing Record 13 of Set 3 | turayf
# Processing Record 14 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 3 | nuuk
# Processing Record 16 of Set 3 | chokurdakh
# Processing Record 17 of Set 3 | tiksi
# Processing Record 18 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 3 | lorengau
# Processing Record 20 of Set 3 | isangel
# Processing Record 21 of Set 3 | banjar
# Processing Record 22 of Set 3 | barrow
# Processing Record 23 of Set 3 | phulji
# Processing Record 24 of Set 3 | lagoa
# Processing Record 25 of Set 3 | berlevag
# Processing Record 26 of Set 3 | ulaanbaatar
# Processing Record 27 of Set 3 | kavieng
# Processing Record 28 of Set 3 | olenino
# Processing Record 29 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 3 | rolla
# Processing Record 31 of Set 3 | wuwei
# Processing Record 32 of Set 3 | mahebourg
# Processing Record 33 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 34 of Set 3 | novoagansk
# Processing Record 35 of Set 3 | rocha
# Processing Record 36 of Set 3 | bubaque
# Processing Record 37 of Set 3 | pochutla
# Processing Record 38 of Set 3 | fuyu
# Processing Record 39 of Set 3 | lensk
# Processing Record 40 of Set 3 | pisco
# Processing Record 41 of Set 3 | ulaangom
# Processing Record 42 of Set 3 | provideniya
# Processing Record 43 of Set 3 | belaya gora
# Processing Record 44 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 3 | raymondville
# Processing Record 46 of Set 3 | tamandare
# Processing Record 47 of Set 3 | seymchan
# Processing Record 48 of Set 3 | lewistown
# Processing Record 49 of Set 3 | whitecourt
# Processing Record 50 of Set 3 | tautira
# Processing Record 1 of Set 4 | marevo
# Processing Record 2 of Set 4 | svay rieng
# Processing Record 3 of Set 4 | tuktoyaktuk
# Processing Record 4 of Set 4 | maniitsoq
# Processing Record 5 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 4 | henties bay
# Processing Record 7 of Set 4 | port hardy
# Processing Record 8 of Set 4 | velyka pysarivka
# Processing Record 9 of Set 4 | puerto escondido
# Processing Record 10 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 11 of Set 4 | chuy
# Processing Record 12 of Set 4 | quatre cocos
# Processing Record 13 of Set 4 | monrovia
# Processing Record 14 of Set 4 | mahon
# Processing Record 15 of Set 4 | codo
# Processing Record 16 of Set 4 | pimentel
# Processing Record 17 of Set 4 | bethel
# Processing Record 18 of Set 4 | iqaluit
# Processing Record 19 of Set 4 | vestmannaeyjar
# Processing Record 20 of Set 4 | bonavista
# Processing Record 21 of Set 4 | port lincoln
# Processing Record 22 of Set 4 | arraial do cabo
# Processing Record 23 of Set 4 | kungurtug
# Processing Record 24 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 4 | victoria
# Processing Record 26 of Set 4 | kuching
# Processing Record 27 of Set 4 | sarkand
# Processing Record 28 of Set 4 | saquena
# Processing Record 29 of Set 4 | coquimbo
# Processing Record 30 of Set 4 | sao raimundo das mangabeiras
# Processing Record 31 of Set 4 | ahipara
# Processing Record 32 of Set 4 | narrabri
# Processing Record 33 of Set 4 | avarua
# Processing Record 34 of Set 4 | ahuimanu
# Processing Record 35 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 4 | olga
# Processing Record 37 of Set 4 | karatau
# Processing Record 38 of Set 4 | caravelas
# Processing Record 39 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 4 | chiredzi
# Processing Record 42 of Set 4 | turukhansk
# Processing Record 43 of Set 4 | bengkulu
# Processing Record 44 of Set 4 | mitsamiouli
# Processing Record 45 of Set 4 | thompson
# Processing Record 46 of Set 4 | smoky lake
# Processing Record 47 of Set 4 | kandrian
# Processing Record 48 of Set 4 | yankton
# Processing Record 49 of Set 4 | rorvik
# Processing Record 50 of Set 4 | yunjinghong
# City not found. Skipping...
# Processing Record 1 of Set 5 | hurricane
# Processing Record 2 of Set 5 | panjab
# Processing Record 3 of Set 5 | omboue
# Processing Record 4 of Set 5 | bowen
# Processing Record 5 of Set 5 | pevek
# Processing Record 6 of Set 5 | nishihara
# Processing Record 7 of Set 5 | flin flon
# Processing Record 8 of Set 5 | veraval
# Processing Record 9 of Set 5 | bloomfield
# Processing Record 10 of Set 5 | cidreira
# Processing Record 11 of Set 5 | nikolskoye
# Processing Record 12 of Set 5 | yellowknife
# Processing Record 13 of Set 5 | san francisco
# Processing Record 14 of Set 5 | krasnoyarskiy
# Processing Record 15 of Set 5 | sechura
# Processing Record 16 of Set 5 | port elizabeth
# Processing Record 17 of Set 5 | kermanshah
# Processing Record 18 of Set 5 | kruisfontein
# Processing Record 19 of Set 5 | katsuura
# Processing Record 20 of Set 5 | saskylakh
# Processing Record 21 of Set 5 | hami
# Processing Record 22 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 5 | georgetown
# Processing Record 24 of Set 5 | marsh harbour
# Processing Record 25 of Set 5 | viedma
# Processing Record 26 of Set 5 | huarmey
# Processing Record 27 of Set 5 | devarkonda
# Processing Record 28 of Set 5 | laguna
# Processing Record 29 of Set 5 | cochrane
# Processing Record 30 of Set 5 | norden
# Processing Record 31 of Set 5 | chicama
# Processing Record 32 of Set 5 | amuntai
# Processing Record 33 of Set 5 | hutchinson
# Processing Record 34 of Set 5 | srednekolymsk
# Processing Record 35 of Set 5 | kilindoni
# Processing Record 36 of Set 5 | emirdag
# Processing Record 37 of Set 5 | payson
# Processing Record 38 of Set 5 | riberalta
# Processing Record 39 of Set 5 | leku
# Processing Record 40 of Set 5 | sibolga
# Processing Record 41 of Set 5 | bubanza
# Processing Record 42 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 5 | beyneu
# Processing Record 44 of Set 5 | paraiso
# Processing Record 45 of Set 5 | sovetskaya gavan
# Processing Record 46 of Set 5 | luoyang
# Processing Record 47 of Set 5 | kavaratti
# Processing Record 48 of Set 5 | tokyo
# Processing Record 49 of Set 5 | lompoc
# Processing Record 50 of Set 5 | beloha
# Processing Record 1 of Set 6 | nicolet
# Processing Record 2 of Set 6 | kaitangata
# Processing Record 3 of Set 6 | russell
# Processing Record 4 of Set 6 | tiarei
# Processing Record 5 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 6 | ialibu
# Processing Record 8 of Set 6 | yerbogachen
# Processing Record 9 of Set 6 | taltal
# Processing Record 10 of Set 6 | havelock
# Processing Record 11 of Set 6 | geraldton
# Processing Record 12 of Set 6 | port macquarie
# Processing Record 13 of Set 6 | ilulissat
# Processing Record 14 of Set 6 | tuatapere
# Processing Record 15 of Set 6 | novyy urengoy
# Processing Record 16 of Set 6 | marzuq
# Processing Record 17 of Set 6 | vostok
# Processing Record 18 of Set 6 | itarema
# Processing Record 19 of Set 6 | hobyo
# Processing Record 20 of Set 6 | bandarbeyla
# Processing Record 21 of Set 6 | maua
# Processing Record 22 of Set 6 | spirit river
# Processing Record 23 of Set 6 | norrtalje
# Processing Record 24 of Set 6 | kuah
# Processing Record 25 of Set 6 | polunochnoye
# Processing Record 26 of Set 6 | namanga
# Processing Record 27 of Set 6 | prado
# Processing Record 28 of Set 6 | shache
# Processing Record 29 of Set 6 | waingapu
# Processing Record 30 of Set 6 | astorga
# Processing Record 31 of Set 6 | poum
# Processing Record 32 of Set 6 | digby
# Processing Record 33 of Set 6 | yulara
# Processing Record 34 of Set 6 | iwanai
# Processing Record 35 of Set 6 | williston
# Processing Record 36 of Set 6 | udomlya
# Processing Record 37 of Set 6 | nabire
# Processing Record 38 of Set 6 | atar
# Processing Record 39 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 40 of Set 6 | beringovskiy
# Processing Record 41 of Set 6 | praia da vitoria
# Processing Record 42 of Set 6 | vila franca do campo
# Processing Record 43 of Set 6 | astoria
# Processing Record 44 of Set 6 | nata
# Processing Record 45 of Set 6 | horodnytsya
# Processing Record 46 of Set 6 | ouallam
# Processing Record 47 of Set 6 | milingimbi
# City not found. Skipping...
# Processing Record 48 of Set 6 | port blair
# Processing Record 49 of Set 6 | kattivakkam
# Processing Record 50 of Set 6 | zhireken
# Processing Record 1 of Set 7 | saint-georges
# Processing Record 2 of Set 7 | waitati
# Processing Record 3 of Set 7 | la romana
# Processing Record 4 of Set 7 | lavrentiya
# Processing Record 5 of Set 7 | miri
# Processing Record 6 of Set 7 | hervey bay
# Processing Record 7 of Set 7 | verkh-usugli
# Processing Record 8 of Set 7 | ambilobe
# Processing Record 9 of Set 7 | axim
# Processing Record 10 of Set 7 | jalu
# Processing Record 11 of Set 7 | grindavik
# Processing Record 12 of Set 7 | katobu
# Processing Record 13 of Set 7 | necochea
# Processing Record 14 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 7 | pringsewu
# Processing Record 16 of Set 7 | nome
# Processing Record 17 of Set 7 | poya
# Processing Record 18 of Set 7 | karangampel
# Processing Record 19 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 20 of Set 7 | shilong
# Processing Record 21 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 22 of Set 7 | curaca
# Processing Record 23 of Set 7 | honiara
# Processing Record 24 of Set 7 | vanavara
# Processing Record 25 of Set 7 | baruun-urt
# Processing Record 26 of Set 7 | san cristobal
# Processing Record 27 of Set 7 | sao raimundo nonato
# Processing Record 28 of Set 7 | mayo
# Processing Record 29 of Set 7 | asyut
# Processing Record 30 of Set 7 | guerrero negro
# Processing Record 31 of Set 7 | alice springs
# Processing Record 32 of Set 7 | opuwo
# Processing Record 33 of Set 7 | ambulu
# Processing Record 34 of Set 7 | kondinskoye
# Processing Record 35 of Set 7 | borovoy
# Processing Record 36 of Set 7 | misratah
# Processing Record 37 of Set 7 | pedernales
# Processing Record 38 of Set 7 | krasnoselkup
# Processing Record 39 of Set 7 | korbach
# Processing Record 40 of Set 7 | moengo
# Processing Record 41 of Set 7 | nanortalik
# Processing Record 42 of Set 7 | komsomolskiy
# Processing Record 43 of Set 7 | zhangye
# Processing Record 44 of Set 7 | bandar-e anzali
# Processing Record 45 of Set 7 | mount gambier
# Processing Record 46 of Set 7 | aswan
# Processing Record 47 of Set 7 | namibe
# Processing Record 48 of Set 7 | mattru
# Processing Record 49 of Set 7 | kurchum
# Processing Record 50 of Set 7 | saldanha
# Processing Record 1 of Set 8 | fairview
# Processing Record 2 of Set 8 | nelson bay
# Processing Record 3 of Set 8 | channel-port aux basques
# Processing Record 4 of Set 8 | bambous virieux
# Processing Record 5 of Set 8 | semenyih
# Processing Record 6 of Set 8 | biak
# Processing Record 7 of Set 8 | vila
# Processing Record 8 of Set 8 | tomatlan
# Processing Record 9 of Set 8 | yangjiang
# Processing Record 10 of Set 8 | kaeo
# Processing Record 11 of Set 8 | oranjemund
# Processing Record 12 of Set 8 | vao
# Processing Record 13 of Set 8 | porgera
# Processing Record 14 of Set 8 | cooma
# Processing Record 15 of Set 8 | dongkan
# Processing Record 16 of Set 8 | luanda
# Processing Record 17 of Set 8 | luga
# Processing Record 18 of Set 8 | walvis bay
# Processing Record 19 of Set 8 | arucas
# Processing Record 20 of Set 8 | sembakung
# Processing Record 21 of Set 8 | phan thiet
# Processing Record 22 of Set 8 | sturgis
# Processing Record 23 of Set 8 | idaho falls
# Processing Record 24 of Set 8 | bosaso
# Processing Record 25 of Set 8 | suez
# Processing Record 26 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 8 | rawson
# Processing Record 28 of Set 8 | kjopsvik
# Processing Record 29 of Set 8 | rawlins
# Processing Record 30 of Set 8 | gouyave
# Processing Record 31 of Set 8 | tongliao
# Processing Record 32 of Set 8 | ribeira grande
# Processing Record 33 of Set 8 | grand gaube
# Processing Record 34 of Set 8 | praya
# Processing Record 35 of Set 8 | port keats
# Processing Record 36 of Set 8 | esperance
# Processing Record 37 of Set 8 | tilichiki
# Processing Record 38 of Set 8 | herat
# Processing Record 39 of Set 8 | blagoyevo
# Processing Record 40 of Set 8 | lata
# Processing Record 41 of Set 8 | peleduy
# Processing Record 42 of Set 8 | inongo
# Processing Record 43 of Set 8 | mogadishu
# Processing Record 44 of Set 8 | sulangan
# Processing Record 45 of Set 8 | thinadhoo
# Processing Record 46 of Set 8 | qarchi gak
# Processing Record 47 of Set 8 | nobres
# Processing Record 48 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 49 of Set 8 | bambanglipuro
# Processing Record 50 of Set 8 | zyryanka
# Processing Record 1 of Set 9 | flinders
# Processing Record 2 of Set 9 | conakry
# Processing Record 3 of Set 9 | ancud
# Processing Record 4 of Set 9 | alice
# Processing Record 5 of Set 9 | robertsport
# Processing Record 6 of Set 9 | civitanova marche
# Processing Record 7 of Set 9 | george
# Processing Record 8 of Set 9 | kerema
# Processing Record 9 of Set 9 | brae
# Processing Record 10 of Set 9 | cabo san lucas
# Processing Record 11 of Set 9 | mareeba
# Processing Record 12 of Set 9 | champerico
# Processing Record 13 of Set 9 | northam
# Processing Record 14 of Set 9 | khorramshahr
# Processing Record 15 of Set 9 | ostrovnoy
# Processing Record 16 of Set 9 | cap malheureux
# Processing Record 17 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 9 | erenhot
# Processing Record 19 of Set 9 | wilmington
# Processing Record 20 of Set 9 | coihaique
# Processing Record 21 of Set 9 | la macarena
# Processing Record 22 of Set 9 | ormara
# Processing Record 23 of Set 9 | kahului
# Processing Record 24 of Set 9 | forbes
# Processing Record 25 of Set 9 | hofn
# Processing Record 26 of Set 9 | cravo norte
# Processing Record 27 of Set 9 | ishinomaki
# Processing Record 28 of Set 9 | san jeronimo
# Processing Record 29 of Set 9 | mantua
# Processing Record 30 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 31 of Set 9 | tena
# Processing Record 32 of Set 9 | nampula
# Processing Record 33 of Set 9 | moose factory
# Processing Record 34 of Set 9 | orcopampa
# Processing Record 35 of Set 9 | pahrump
# Processing Record 36 of Set 9 | lasa
# Processing Record 37 of Set 9 | faanui
# Processing Record 38 of Set 9 | naron
# Processing Record 39 of Set 9 | virpur
# Processing Record 40 of Set 9 | poquoson
# Processing Record 41 of Set 9 | nioki
# Processing Record 42 of Set 9 | pangnirtung
# Processing Record 43 of Set 9 | samagaltay
# Processing Record 44 of Set 9 | tigzirt
# Processing Record 45 of Set 9 | jiazi
# Processing Record 46 of Set 9 | onega
# Processing Record 47 of Set 9 | ipameri
# Processing Record 48 of Set 9 | larsnes
# Processing Record 49 of Set 9 | leh
# Processing Record 50 of Set 9 | nouadhibou
# Processing Record 1 of Set 10 | danville
# Processing Record 2 of Set 10 | touros
# Processing Record 3 of Set 10 | solnechnyy
# Processing Record 4 of Set 10 | klaksvik
# Processing Record 5 of Set 10 | pullman
# Processing Record 6 of Set 10 | punta alta
# Processing Record 7 of Set 10 | adrar
# Processing Record 8 of Set 10 | togur
# Processing Record 9 of Set 10 | tual
# Processing Record 10 of Set 10 | presidencia roque saenz pena
# Processing Record 11 of Set 10 | sokna
# Processing Record 12 of Set 10 | komsomolsk
# Processing Record 13 of Set 10 | agbor
# Processing Record 14 of Set 10 | nioro
# Processing Record 15 of Set 10 | goderich
# Processing Record 16 of Set 10 | aasiaat
# Processing Record 17 of Set 10 | gemena
# Processing Record 18 of Set 10 | anupgarh
# Processing Record 19 of Set 10 | anapskaya
# Processing Record 20 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 21 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 22 of Set 10 | abu zabad
# Processing Record 23 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 24 of Set 10 | zhangjiakou
# Processing Record 25 of Set 10 | datong
# Processing Record 26 of Set 10 | fujin
# Processing Record 27 of Set 10 | talnakh
# Processing Record 28 of Set 10 | camana
# Processing Record 29 of Set 10 | richards bay
# Processing Record 30 of Set 10 | achisay
# City not found. Skipping...
# Processing Record 31 of Set 10 | gravelbourg
# Processing Record 32 of Set 10 | kirovskiy
# Processing Record 33 of Set 10 | kaka
# Processing Record 34 of Set 10 | ponta delgada
# Processing Record 35 of Set 10 | rio grande
# Processing Record 36 of Set 10 | okha
# Processing Record 37 of Set 10 | jeremie
# Processing Record 38 of Set 10 | portree
# Processing Record 39 of Set 10 | koslan
# Processing Record 40 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 10 | marovoay
# Processing Record 42 of Set 10 | ambon
# Processing Record 43 of Set 10 | oparino
# Processing Record 44 of Set 10 | fort nelson
# Processing Record 45 of Set 10 | svetlyy
# Processing Record 46 of Set 10 | bac
# Processing Record 47 of Set 10 | casino
# Processing Record 48 of Set 10 | saint-pierre
# Processing Record 49 of Set 10 | lagos
# Processing Record 50 of Set 10 | dauphin
# Processing Record 1 of Set 11 | sur
# Processing Record 2 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 11 | bilibino
# Processing Record 4 of Set 11 | broken hill
# Processing Record 5 of Set 11 | nizhniy odes
# Processing Record 6 of Set 11 | baker city
# Processing Record 7 of Set 11 | tura
# Processing Record 8 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 11 | buala
# Processing Record 10 of Set 11 | concordia
# Processing Record 11 of Set 11 | cedar city
# Processing Record 12 of Set 11 | salamiyah
# Processing Record 13 of Set 11 | vinh
# Processing Record 14 of Set 11 | boyolangu
# Processing Record 15 of Set 11 | avera
# Processing Record 16 of Set 11 | itacoatiara
# Processing Record 17 of Set 11 | tucurui
# Processing Record 18 of Set 11 | maldonado
# Processing Record 19 of Set 11 | koboldo
# City not found. Skipping...
# Processing Record 20 of Set 11 | kimbe
# Processing Record 21 of Set 11 | tessalit
# Processing Record 22 of Set 11 | mezen
# Processing Record 23 of Set 11 | hermiston
# Processing Record 24 of Set 11 | kyra
# Processing Record 25 of Set 11 | ganlose
# Processing Record 26 of Set 11 | lingao
# Processing Record 27 of Set 11 | makakilo city
# Processing Record 28 of Set 11 | kearney
# Processing Record 29 of Set 11 | plouzane
# Processing Record 30 of Set 11 | jinchang
# Processing Record 31 of Set 11 | caranavi
# Processing Record 32 of Set 11 | mukhen
# Processing Record 33 of Set 11 | santa maria da vitoria
# Processing Record 34 of Set 11 | kismayo
# Processing Record 35 of Set 11 | yar-sale
# Processing Record 36 of Set 11 | manadhoo
# Processing Record 37 of Set 11 | santa marta
# Processing Record 38 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 11 | lundazi
# Processing Record 40 of Set 11 | camacha
# Processing Record 41 of Set 11 | asau
# Processing Record 42 of Set 11 | bayan
# Processing Record 43 of Set 11 | verkh-chebula
# Processing Record 44 of Set 11 | san patricio
# Processing Record 45 of Set 11 | fairbanks
# Processing Record 46 of Set 11 | husavik
# Processing Record 47 of Set 11 | sabang
# Processing Record 48 of Set 11 | mwandiga
# Processing Record 49 of Set 11 | natal
# Processing Record 50 of Set 11 | maple creek
# Processing Record 1 of Set 12 | wanning
# Processing Record 2 of Set 12 | upernavik
# Processing Record 3 of Set 12 | casas grandes
# Processing Record 4 of Set 12 | flagstaff
# Processing Record 5 of Set 12 | tiznit
# Processing Record 6 of Set 12 | mongu
# Processing Record 7 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 12 | los llanos de aridane
# Processing Record 9 of Set 12 | aksu
# Processing Record 10 of Set 12 | dakar
# Processing Record 11 of Set 12 | auki
# Processing Record 12 of Set 12 | awbari
# Processing Record 13 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 12 | anadyr
# Processing Record 15 of Set 12 | cockburn town
# Processing Record 16 of Set 12 | labuhan
# Processing Record 17 of Set 12 | bria
# Processing Record 18 of Set 12 | bijar
# Processing Record 19 of Set 12 | sobolevo
# Processing Record 20 of Set 12 | inegol
# Processing Record 21 of Set 12 | maihar
# Processing Record 22 of Set 12 | wexford
# Processing Record 23 of Set 12 | saint-augustin
# Processing Record 24 of Set 12 | kushmurun
# Processing Record 25 of Set 12 | byron bay
# Processing Record 26 of Set 12 | lere
# Processing Record 27 of Set 12 | springbok
# Processing Record 28 of Set 12 | trogir
# Processing Record 29 of Set 12 | prudentopolis
# Processing Record 30 of Set 12 | hualmay
# Processing Record 31 of Set 12 | shenjiamen
# Processing Record 32 of Set 12 | dondo
# Processing Record 33 of Set 12 | freetown
# Processing Record 34 of Set 12 | sachin
# Processing Record 35 of Set 12 | kenai
# Processing Record 36 of Set 12 | tazovskiy
# Processing Record 37 of Set 12 | lucapa
# Processing Record 38 of Set 12 | saint-joseph
# Processing Record 39 of Set 12 | la ronge
# Processing Record 40 of Set 12 | staroutkinsk
# Processing Record 41 of Set 12 | jacqueville
# Processing Record 42 of Set 12 | meulaboh
# Processing Record 43 of Set 12 | rio gallegos
# Processing Record 44 of Set 12 | novita
# Processing Record 45 of Set 12 | sidi ali
# Processing Record 46 of Set 12 | nyimba
# Processing Record 47 of Set 12 | marang
# Processing Record 48 of Set 12 | maceio
# Processing Record 49 of Set 12 | dakoro
# Processing Record 50 of Set 12 | yaan
# Processing Record 1 of Set 13 | roma
# Processing Record 2 of Set 13 | del rio
# Processing Record 3 of Set 13 | najran
# Processing Record 4 of Set 13 | leningradskiy
# Processing Record 5 of Set 13 | juiz de fora
# Processing Record 6 of Set 13 | samarai
# Processing Record 7 of Set 13 | leshukonskoye
# Processing Record 8 of Set 13 | ambatondrazaka
# Processing Record 9 of Set 13 | morlaix
# Processing Record 10 of Set 13 | lakatoro
# Processing Record 11 of Set 13 | parfenyevo
# Processing Record 12 of Set 13 | peniche
# Processing Record 13 of Set 13 | saint anthony
# Processing Record 14 of Set 13 | kohlu
# Processing Record 15 of Set 13 | hirara
# Processing Record 16 of Set 13 | grajau
# Processing Record 17 of Set 13 | haines junction
# Processing Record 18 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 19 of Set 13 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 20 of Set 13 | verkhoshizhemye
# Processing Record 21 of Set 13 | yeppoon
# Processing Record 22 of Set 13 | zharkent
# Processing Record 23 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 13 | kungalv
# Processing Record 25 of Set 13 | barcelona
# Processing Record 26 of Set 13 | ozernovskiy
# Processing Record 27 of Set 13 | hainichen
# Processing Record 28 of Set 13 | huron
# Processing Record 29 of Set 13 | eirunepe
# Processing Record 30 of Set 13 | enshi
# Processing Record 31 of Set 13 | cardston
# Processing Record 32 of Set 13 | camargo
# Processing Record 33 of Set 13 | morondava
# Processing Record 34 of Set 13 | wonthaggi
# Processing Record 35 of Set 13 | ilinskiy
# Processing Record 36 of Set 13 | hohhot
# Processing Record 37 of Set 13 | spassk
# Processing Record 38 of Set 13 | koyilandi
# City not found. Skipping...
# Processing Record 39 of Set 13 | alyangula
# Processing Record 40 of Set 13 | aykhal
# Processing Record 41 of Set 13 | kayseri
# Processing Record 42 of Set 13 | mujiayingzi
# Processing Record 43 of Set 13 | comodoro rivadavia
# Processing Record 44 of Set 13 | price
# Processing Record 45 of Set 13 | tipperary
# Processing Record 46 of Set 13 | hovd
# Processing Record 47 of Set 13 | te anau
# Processing Record 48 of Set 13 | lanzhou
# Processing Record 49 of Set 13 | diphu
# Processing Record 50 of Set 13 | souillac
# Processing Record 1 of Set 14 | koumac
# Processing Record 2 of Set 14 | ust-koksa
# Processing Record 3 of Set 14 | cayenne
# Processing Record 4 of Set 14 | salcaja
# Processing Record 5 of Set 14 | sorland
# Processing Record 6 of Set 14 | turbat
# Processing Record 7 of Set 14 | nokaneng
# Processing Record 8 of Set 14 | yilan
# Processing Record 9 of Set 14 | carbonia
# Processing Record 10 of Set 14 | monte patria
# Processing Record 11 of Set 14 | nemuro
# Processing Record 12 of Set 14 | powell
# Processing Record 13 of Set 14 | san
# Processing Record 14 of Set 14 | dong hoi
# Processing Record 15 of Set 14 | bonthe
# Processing Record 16 of Set 14 | bajil
# Processing Record 17 of Set 14 | san jose
# Processing Record 18 of Set 14 | kazanlak
# Processing Record 19 of Set 14 | hay river
# Processing Record 20 of Set 14 | mendahara
# City not found. Skipping...
# Processing Record 21 of Set 14 | castanos
# Processing Record 22 of Set 14 | diffa
# Processing Record 23 of Set 14 | pskov
# Processing Record 24 of Set 14 | yartsevo
# Processing Record 25 of Set 14 | paucartambo
# City not found. Skipping...
# Processing Record 26 of Set 14 | kristiinankaupunki
# Processing Record 27 of Set 14 | kothen
# Processing Record 28 of Set 14 | emba
# Processing Record 29 of Set 14 | mamallapuram
# Processing Record 30 of Set 14 | kyren
# Processing Record 31 of Set 14 | nigran
# Processing Record 32 of Set 14 | mongo
# Processing Record 33 of Set 14 | vadso
# Processing Record 34 of Set 14 | barcelos
# Processing Record 35 of Set 14 | benguela
# Processing Record 36 of Set 14 | salisbury
# Processing Record 37 of Set 14 | tommot
# Processing Record 38 of Set 14 | peterhead
# Processing Record 39 of Set 14 | roald
# Processing Record 40 of Set 14 | ecatepec
# Processing Record 41 of Set 14 | bucak
# Processing Record 42 of Set 14 | toulepleu
# City not found. Skipping...
# Processing Record 43 of Set 14 | raudeberg
# Processing Record 44 of Set 14 | sumbe
# Processing Record 45 of Set 14 | manono
# Processing Record 46 of Set 14 | brezova
# Processing Record 47 of Set 14 | padang
# Processing Record 48 of Set 14 | varkaus
# Processing Record 49 of Set 14 | puerto madero
# Processing Record 50 of Set 14 | shimoda
# Processing Record 1 of Set 15 | cukai
# Processing Record 2 of Set 15 | takaka
# Processing Record 3 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 4 of Set 15 | phangnga
# Processing Record 5 of Set 15 | arlit
# Processing Record 6 of Set 15 | ulladulla
# Processing Record 7 of Set 15 | creel
# Processing Record 8 of Set 15 | nauta
# Processing Record 9 of Set 15 | dipkarpaz
# City not found. Skipping...
# Processing Record 10 of Set 15 | olafsvik
# Processing Record 11 of Set 15 | boa vista
# Processing Record 12 of Set 15 | dongobesh
# Processing Record 13 of Set 15 | la paz
# Processing Record 14 of Set 15 | bulanash
# Processing Record 15 of Set 15 | chateauroux
# Processing Record 16 of Set 15 | batagay-alyta
# Processing Record 17 of Set 15 | burkhala
# City not found. Skipping...
# Processing Record 18 of Set 15 | palmer
# Processing Record 19 of Set 15 | beira
# Processing Record 20 of Set 15 | amarante do maranhao
# Processing Record 21 of Set 15 | mustasaari
# Processing Record 22 of Set 15 | anloga
# Processing Record 23 of Set 15 | deputatskiy
# Processing Record 24 of Set 15 | san martin
# Processing Record 25 of Set 15 | corinto
# Processing Record 26 of Set 15 | rincon
# Processing Record 27 of Set 15 | teahupoo
# Processing Record 28 of Set 15 | colchester
# Processing Record 29 of Set 15 | llata
# Processing Record 30 of Set 15 | college
# Processing Record 31 of Set 15 | sandpoint
# Processing Record 32 of Set 15 | yabrud
# Processing Record 33 of Set 15 | port-gentil
# Processing Record 34 of Set 15 | amahai
# Processing Record 35 of Set 15 | boguchany
# Processing Record 36 of Set 15 | launceston
# Processing Record 37 of Set 15 | kasongo-lunda
# Processing Record 38 of Set 15 | metro
# Processing Record 39 of Set 15 | tecoanapa
# Processing Record 40 of Set 15 | mount pleasant
# Processing Record 41 of Set 15 | bara
# Processing Record 42 of Set 15 | jimenez
# Processing Record 43 of Set 15 | vanderhoof
# Processing Record 44 of Set 15 | kulu
# Processing Record 45 of Set 15 | omsukchan
# Processing Record 46 of Set 15 | tikaitnagar
# Processing Record 47 of Set 15 | sinnamary
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Rikitea -23.1203 -134.9692    298.88        65          71        3.43
# 1  Soligalich  59.0778   42.2864    266.06        95         100        3.43
# 2       Bondo   3.8146   23.6866    290.72        55          37        1.00
# 3        Soyo  -6.1349   12.3689    298.43        89          98        2.47
# 4       Vaini -21.2000 -175.2000    300.24        74          58        6.99
# 5    Tasiilaq  65.6145  -37.6368    262.24        80          84        3.45
# 6      Atuona  -9.8000 -139.0333    299.14        75           9        9.23
# 7    Hermanus -34.4187   19.2345    295.32        82           2        2.76
# 8       Jaque   7.5175  -78.1703    296.79        82          35        2.69
# 9      Albany  42.6001  -73.9662    263.11        74           6        0.77
#
#   Country Current Conditions                 Date
# 0      PF      broken clouds  2022-02-01 04:37:21
# 1      RU               snow  2022-02-01 04:37:22
# 2      CD   scattered clouds  2022-02-01 04:37:22
# 3      AO         light rain  2022-02-01 04:37:23
# 4      TO         light rain  2022-02-01 04:34:53
# 5      GL      broken clouds  2022-02-01 04:37:23
# 6      PF          clear sky  2022-02-01 04:35:11
# 7      ZA          clear sky  2022-02-01 04:37:24
# 8      PA   scattered clouds  2022-02-01 04:37:24
# 9      US          clear sky  2022-02-01 04:36:51

# %%
new_column_order = ["City", "Country", "Lat", "Lng","Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Conditions"]
city_data_df = city_data_df[new_column_order]
# display (city_data_df)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Rikitea      PF -23.1203 -134.9692    298.88        65          71
# 1  Soligalich      RU  59.0778   42.2864    266.06        95         100
# 2       Bondo      CD   3.8146   23.6866    290.72        55          37
# 3        Soyo      AO  -6.1349   12.3689    298.43        89          98
# 4       Vaini      TO -21.2000 -175.2000    300.24        74          58
# 5    Tasiilaq      GL  65.6145  -37.6368    262.24        80          84
# 6      Atuona      PF  -9.8000 -139.0333    299.14        75           9
# 7    Hermanus      ZA -34.4187   19.2345    295.32        82           2
# 8       Jaque      PA   7.5175  -78.1703    296.79        82          35
# 9      Albany      US  42.6001  -73.9662    263.11        74           6
#
#    Wind Speed Current Conditions
# 0        3.43      broken clouds
# 1        3.43               snow
# 2        1.00   scattered clouds
# 3        2.47         light rain
# 4        6.99         light rain
# 5        3.45      broken clouds
# 6        9.23          clear sky
# 7        2.76          clear sky
# 8        2.69   scattered clouds
# 9        0.77          clear sky

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
